# %% [markdown]
# # Functions

# %%
# A function in Python is a block of reusable code that performs a specific task when called.

# Function is of 2 types ( Define the function and call the function)

# %%
# for defining

def hello():
    print("Hello World")

hello()
# Out:
# Hello World

# %%
def add():
    x=12
    y=34
    print(x+y)

add()
# Out:
# 46

# %%
# OR

def add(x,y):    # Parameters
    print(x+y)

add(4,9)         #Arguments
add(12,89)
# Out:
# 13
# 101

# %%
def rect(length,breadth):
    area=length*breadth
    print("The area of Rectangle is :",area)

rect(20,30)
# Out:
# The area of Rectangle is : 600

# %%
def hello(*name):
    print ("hello! My name is",name[2])

hello('John.','Lissa.','Peter.')
# Out:
# hello! My name is Peter.

# %% [markdown]
# # Return Statement

# %%
# Return keyword in pythin is used to exit a function and return the value of the function.

# %%
def hello():
    return ("Hello World.")

print(hello())
# Out:
# Hello World.

# %%
def add(a,b):
    return ("The addition of two number is:",a+b)

print(add(12,48),type(add))
# Out:
# ('The addition of two number is:', 60) <class 'function'>

# %%
def add(a, b):
    return f"The addition of two number is: {a + b}"

print(add(12, 48))
# Out:
# The addition of two number is: 60

# %% [markdown]
# # Recursion in Python

# %%
# Recursion in most commonly used mathematical and programming concept.
# In simple words, recursion means a function call itself , 
# giivng us a benefit of looping through data in order to get a result.

# %%
# print (add(12,4))
# Recursion 

def hello():
    print("Hello")
    return hello()

print(hello())
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...

# %%
def fact(n):
    if n==1:
        return 1
    else:
        return n*fact(n-1)

print(fact(5))
# Out:
# 120

# %%
# ADVANTAGES of Recursion:

# 1. They make the code look clean and organized.
# 2. By the use of recursive functions, a complex task can be broken down into small sub-parts.
# 3. Sequence generation becomes easier.


# DISADVANTAGES:

# 1. Recursive Functions take up a lot of memory.
# 2. Sometimes the logic becomes hard to follow.

# %% [markdown]
# # Lambda Function in Python

# %%
# It is used when an anonymous function is required for a short period of time.
# It can take numerous arguments.
# It can only have one expression.

# %%
a = lambda b: b*5
print(a(4))
# Out:
# 20

# %%
x = lambda a,b,c: (a+b)*c
print(x(7,3,4))
# Out:
# 40

# %% [markdown]
# # Local and Global Variable

# %%
# Variable is a contianer in which we store data and also do increment and decrement according to program.

# %%
# Local Variables:
# Local Variables are restricted to only one block of code and cannot be changed throughout the program.

# Global Variables:
# Global variables are not restricted to one block of code and that can be changed throughout the program.

# %%
# Local variable

x=24
print("first variable x is :",x)
def hello():
    x=25
    return(x)

print(hello())
print(x)
# Out:
# first variable x is : 24
# 25
# 24
